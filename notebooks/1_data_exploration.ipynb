# %%
# imports & config
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path("../data")
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# load data
# Example names—you’ll confirm with ls output
df = pd.read_csv(DATA_DIR / "Base.csv")  # or the main transactions file provided
df.shape, df.dtypes.head()
# Out:
# ((1000000, 32),
#  fraud_bool                        int64
#  income                          float64
#  name_email_similarity           float64
#  prev_address_months_count         int64
#  current_address_months_count      int64
#  dtype: object)

# %%
# data preview
df.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
# quick profile
df.isna().sum().sort_values(ascending=False).head(32)
# Out:
# fraud_bool                          0
# income                              0
# device_fraud_count                  0
# device_distinct_emails_8w           0
# keep_alive_session                  0
# device_os                           0
# session_length_in_minutes           0
# source                              0
# foreign_request                     0
# proposed_credit_limit               0
# has_other_cards                     0
# bank_months_count                   0
# phone_mobile_valid                  0
# phone_home_valid                    0
# housing_status                      0
# email_is_free                       0
# credit_risk_score                   0
# employment_status                   0
# date_of_birth_distinct_emails_4w    0
# bank_branch_count_8w                0
# velocity_4w                         0
# velocity_24h                        0
# velocity_6h                         0
# zip_count_4w                        0
# payment_type                        0
# ...

# %%
# minimal summary for the report
summary = pd.DataFrame({
    "dtype": df.dtypes,
    "n_missing": df.isna().sum(),
    "n_unique": df.nunique()
}).sort_values("n_missing", ascending=False)
summary.to_csv("../report/feature_summary.csv", index=True)
